# %% [markdown]
# <a href="https://colab.research.google.com/github/rachitss/Quant_Comp_Lab/blob/main/Lab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install qiskit

# %%
pip install qiskit-aer

# %%
from qiskit import QuantumCircuit, assemble
from qiskit.visualization import plot_bloch_multivector
from qiskit_aer import Aer, AerSimulator
from math import pi, sqrt
sim = AerSimulator()

# %%
state1=[1/sqrt(2),1/sqrt(2)]

# %%
qcx = QuantumCircuit(1)
qcx.initialize(state1,0)
qcx.x(0)
qcx.draw(initial_state=True)
# Out:
#       ┌─────────────────────────────┐┌───┐
# q: |0>┤ Initialize(0.70711,0.70711) ├┤ X ├
#       └─────────────────────────────┘└───┘

# %%
qcx.save_statevector()
resultx = sim.run(qcx).result()
statex = resultx.get_statevector()
plot_bloch_multivector(statex)

# %%
statex
# Out:
# Statevector([0.70710678+0.j, 0.70710678+0.j],
#             dims=(2,))

# %%
qcy = QuantumCircuit(1)
qcy.initialize(state1,0)
qcy.y(0)
qcy.draw(initial_state=True)
# Out:
#       ┌─────────────────────────────┐┌───┐
# q: |0>┤ Initialize(0.70711,0.70711) ├┤ Y ├
#       └─────────────────────────────┘└───┘

# %%
qcy.save_statevector()
resulty = sim.run(qcy).result()
statey = resulty.get_statevector()
plot_bloch_multivector(statey)

# %%
statey
# Out:
# Statevector([0.-0.70710678j, 0.+0.70710678j],
#             dims=(2,))

# %%
qcz = QuantumCircuit(1)
qcz.initialize(state1,0)
qcz.z(0)
qcz.draw(initial_state=True)
# Out:
#       ┌─────────────────────────────┐┌───┐
# q: |0>┤ Initialize(0.70711,0.70711) ├┤ Z ├
#       └─────────────────────────────┘└───┘

# %%
qcz.save_statevector()
resultz = sim.run(qcz).result()
statez = resultz.get_statevector()
plot_bloch_multivector(statez)

# %%
statez
# Out:
# Statevector([ 0.70710678+0.j, -0.70710678+0.j],
#             dims=(2,))

# %%
qcs = QuantumCircuit(1)
qcs.initialize(state1,0)
qcs.s(0)
qcs.draw(initial_state=True)
# Out:
#       ┌─────────────────────────────┐┌───┐
# q: |0>┤ Initialize(0.70711,0.70711) ├┤ S ├
#       └─────────────────────────────┘└───┘

# %%
qcs.save_statevector()
results = sim.run(qcs).result()
states = results.get_statevector()
plot_bloch_multivector(states)

# %%
states
# Out:
# Statevector([ 0.70710678+0.j        , -0.        +0.70710678j],
#             dims=(2,))

# %%
qct = QuantumCircuit(1)
qct.initialize(state1,0)
qct.t(0)
qct.draw(initial_state=True)
# Out:
#       ┌─────────────────────────────┐┌───┐
# q: |0>┤ Initialize(0.70711,0.70711) ├┤ T ├
#       └─────────────────────────────┘└───┘

# %%
qct.save_statevector()
resultt = sim.run(qct).result()
statet = resultt.get_statevector()
plot_bloch_multivector(statet)

# %%
statet
# Out:
# Statevector([0.70710678+0.j , 0.5       +0.5j],
#             dims=(2,))

# %%
qcsdg = QuantumCircuit(1)
qcsdg.initialize(state1,0)
qcsdg.sdg(0)
qcsdg.draw(initial_state=True)
# Out:
#       ┌─────────────────────────────┐┌─────┐
# q: |0>┤ Initialize(0.70711,0.70711) ├┤ Sdg ├
#       └─────────────────────────────┘└─────┘

# %%
qcsdg.save_statevector()
resultsdg = sim.run(qcsdg).result()
statesdg = resultsdg.get_statevector()
plot_bloch_multivector(statesdg)

# %%
statesdg
# Out:
# Statevector([0.70710678+0.j        , 0.        -0.70710678j],
#             dims=(2,))

# %%
qctdg = QuantumCircuit(1)
qctdg.initialize(state1,0)
qctdg.tdg(0)
qctdg.draw(initial_state=True)
# Out:
#       ┌─────────────────────────────┐┌─────┐
# q: |0>┤ Initialize(0.70711,0.70711) ├┤ Tdg ├
#       └─────────────────────────────┘└─────┘

# %%
qctdg.save_statevector()
resulttdg = sim.run(qctdg).result()
statetdg = resulttdg.get_statevector()
plot_bloch_multivector(statetdg)

# %%
statetdg
# Out:
# Statevector([0.70710678+0.j , 0.5       -0.5j],
#             dims=(2,))

# %%
qcu = QuantumCircuit(1)
qcu.initialize(state1,0)
qcu.u(pi/2,0,pi,0)
qcu.draw(initial_state=True)
# Out:
#       ┌─────────────────────────────┐┌────────────┐
# q: |0>┤ Initialize(0.70711,0.70711) ├┤ U(π/2,0,π) ├
#       └─────────────────────────────┘└────────────┘

# %%
qch = QuantumCircuit(1)
qch.initialize(state1,0)
qch.h(0)
qch.draw(initial_state=True)
# Out:
#       ┌─────────────────────────────┐┌───┐
# q: |0>┤ Initialize(0.70711,0.70711) ├┤ H ├
#       └─────────────────────────────┘└───┘

# %%
qcu.save_statevector()
resultu = sim.run(qcu).result()
stateu = resultu.get_statevector()
plot_bloch_multivector(stateu)

# %%
qch.save_statevector()
resulth = sim.run(qch).result()
stateh = resulth.get_statevector()
plot_bloch_multivector(stateh)

# %%
stateu
# Out:
# Statevector([ 1.00000000e+00-6.123234e-17j, -1.11022302e-16+6.123234e-17j],
#             dims=(2,))

# %%
stateh
# Out:
# Statevector([ 1.00000000e+00-6.123234e-17j, -1.11022302e-16+6.123234e-17j],
#             dims=(2,))
